# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from datetime import datetime
import itertools
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor, plot_tree
from xgboost import XGBRegressor


import os

# %% [markdown]
# ### Read and Combine the txt files

# %%
# Path to the folder containing the text files
folder_path = r"C:/Users/odoms001/Downloads/IMA_Project/CS_Finance_Data"

# List all files in the folder
file_list = [f for f in os.listdir(folder_path) if f.endswith('.txt')] ## List Comprehension

# Initialize an empty list to store DataFrames
dataframes = []

# Read each file and append the DataFrame to the list
for file_name in file_list:
    file_path = os.path.join(folder_path, file_name)
    df = pd.read_csv(file_path, sep='^', header=0, engine='python', encoding='latin1', on_bad_lines='skip')
    dataframes.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Display the first few rows of the combined DataFrame
combined_df.head()
# Out:
#    RSSD9001  RSSD9999  RSSD9007  RSSD9008  RSSD9132  RSSD9032  RSSD9146  \
# 0   1020180  20040331  20020401  20040822    551111         9      11.0
# 1   1020201  20040331  20001028  20051230    551111         2       1.0
# 2   1020340  20040331  20040301  20040531    551111         7      29.0
# 3   1020395  20040331  20040211  20081230    551111         6       1.0
# 4   1020582  20040331  19980101  20060228    551111         7       1.0
#
#    BHBC3368  BHBC3402  BHBC3516  ...  BHCANC99  BHCKFT42  BHCKFT43  BHCKFT44  \
# 0       0.0       0.0       0.0  ...       NaN       NaN       NaN       NaN
# 1       0.0       0.0       0.0  ...       NaN       NaN       NaN       NaN
# 2       0.0       0.0       0.0  ...       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN  ...       NaN       NaN       NaN       NaN
#
#    BHSPFT42  BHSPFT43  BHSPFT44  BHSPMZ36  BHSPNK60  BHCKMG95
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN
#
# [5 rows x 3099 columns]

# %% [markdown]
# ### Subset some columns:

# %%
smalldf = combined_df[['RSSD9001','RSSD9017', 'RSSD9032', 'RSSD9146', 'RSSD9999', 'BHCK4107', 'BHCK2170']]
smalldf.head()
# Out:
#    RSSD9001                       RSSD9017  RSSD9032  RSSD9146  RSSD9999  \
# 0   1020180   BREMER FINANCIAL CORPORATION         9      11.0  20040331
# 1   1020201                  HSBC USA INC.         2       1.0  20040331
# 2   1020340          HARRIS BANKCORP, INC.         7      29.0  20040331
# 3   1020395  SOUTHERN NATIONAL CORPORATION         6       1.0  20040331
# 4   1020582              WCN BANCORP, INC.         7       1.0  20040331
#
#    BHCK4107     BHCK2170
# 0   68233.0    5721282.0
# 1  883035.0  102501934.0
# 2  276513.0   32344528.0
# 3    2980.0     217529.0
# 4    2692.0     240470.0

# %%
name_dict = {'RSSD9001':'RSSD ID',
             'RSSD9017':'Firm Legal Name',
             'RSSD9032':'FR District Code',
             'RSSD9146':'Bank Count',
             'RSSD9999':'Reporting Date',
             'BHCK4107':'Interest Income',
             'BHCK2170':'Total Assets',
             }
smalldf = smalldf.rename(columns = name_dict)
print(smalldf.shape)
smalldf.head()
# Out:
# (243757, 7)
#    RSSD ID                Firm Legal Name  FR District Code  Bank Count  \
# 0  1020180   BREMER FINANCIAL CORPORATION                 9        11.0
# 1  1020201                  HSBC USA INC.                 2         1.0
# 2  1020340          HARRIS BANKCORP, INC.                 7        29.0
# 3  1020395  SOUTHERN NATIONAL CORPORATION                 6         1.0
# 4  1020582              WCN BANCORP, INC.                 7         1.0
#
#    Reporting Date  Interest Income  Total Assets
# 0        20040331          68233.0     5721282.0
# 1        20040331         883035.0   102501934.0
# 2        20040331         276513.0    32344528.0
# 3        20040331           2980.0      217529.0
# 4        20040331           2692.0      240470.0

# %%
smalldf['Reporting Date'] = pd.to_datetime(smalldf['Reporting Date'], format = "%Y%m%d")

# %%
smalldf.shape
# Out:
# (243757, 7)

# %% [markdown]
# ### Define Quarters and Years

# %%
# Define Quarter

smalldf['Quarter'] = smalldf['Reporting Date'].dt.quarter
# smalldf.head()

# %%
# Define Year

smalldf['Year'] = smalldf['Reporting Date'].dt.year
smalldf.head()
# Out:
#    RSSD ID                Firm Legal Name  FR District Code  Bank Count  \
# 0  1020180   BREMER FINANCIAL CORPORATION                 9        11.0
# 1  1020201                  HSBC USA INC.                 2         1.0
# 2  1020340          HARRIS BANKCORP, INC.                 7        29.0
# 3  1020395  SOUTHERN NATIONAL CORPORATION                 6         1.0
# 4  1020582              WCN BANCORP, INC.                 7         1.0
#
#   Reporting Date  Interest Income  Total Assets  Quarter  Year
# 0     2004-03-31          68233.0     5721282.0        1  2004
# 1     2004-03-31         883035.0   102501934.0        1  2004
# 2     2004-03-31         276513.0    32344528.0        1  2004
# 3     2004-03-31           2980.0      217529.0        1  2004
# 4     2004-03-31           2692.0      240470.0        1  2004

# %% [markdown]
# ## Quaterization

# %%
def quarterize(df, cols_to_process, dt_column):

  # indices is considered to be default
    fq_ids = df[(df[dt_column].dt.month == 3) & (df[dt_column].dt.day == 31)].index
    for col in cols_to_process:

        df[f"Q{col}"] = df[col].diff()
        df.loc[fq_ids, f"Q{col}"] = df.loc[fq_ids, col]
    return df

# %%
ls_dfs = []
for bank in smalldf['RSSD ID'].unique():
    OneBank = smalldf[smalldf["RSSD ID"] == bank].sort_values(by=['Reporting Date'])
    tmp_df = quarterize(OneBank, ["Interest Income"], dt_column="Reporting Date")
    ls_dfs.append(tmp_df)

Quarterized_dfs = pd.concat(ls_dfs, ignore_index=True)
Quarterized_dfs.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code  Bank Count  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9        11.0
# 1  1020180  BREMER FINANCIAL CORPORATION                 9        11.0
# 2  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
# 3  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
# 4  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
#
#   Reporting Date  Interest Income  Total Assets  Quarter  Year  \
# 0     2004-03-31          68233.0     5721282.0        1  2004
# 1     2004-06-30         138086.0     5870480.0        2  2004
# 2     2004-09-30         212489.0     5963700.0        3  2004
# 3     2004-12-31         291916.0     6141519.0        4  2004
# 4     2005-03-31          81656.0     6230236.0        1  2005
#
#    QInterest Income
# 0           68233.0
# 1           69853.0
# 2           74403.0
# 3           79427.0
# 4           81656.0

# %% [markdown]
# ### Normalization

# %%
# Normalize Components
Quarterized_dfs['Normalized Interest Income per Quarter'] = Quarterized_dfs['QInterest Income']/Quarterized_dfs['Total Assets']

# Quarterized_dfs['Normalized Net Interest Income per Quarter'] = Quarterized_dfs['QNet Interest Income']/Quarterized_dfs['Total Assets']

Quarterized_dfs.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code  Bank Count  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9        11.0
# 1  1020180  BREMER FINANCIAL CORPORATION                 9        11.0
# 2  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
# 3  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
# 4  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
#
#   Reporting Date  Interest Income  Total Assets  Quarter  Year  \
# 0     2004-03-31          68233.0     5721282.0        1  2004
# 1     2004-06-30         138086.0     5870480.0        2  2004
# 2     2004-09-30         212489.0     5963700.0        3  2004
# 3     2004-12-31         291916.0     6141519.0        4  2004
# 4     2005-03-31          81656.0     6230236.0        1  2005
#
#    QInterest Income  Normalized Interest Income per Quarter
# 0           68233.0                                0.011926
# 1           69853.0                                0.011899
# 2           74403.0                                0.012476
# 3           79427.0                                0.012933
# 4           81656.0                                0.013106

# %%
Quarterized_dfs.shape
# Out:
# (243757, 11)

# %% [markdown]
# # Considering Macroeconomic Variables

# %% [markdown]
# ### 1. GDP AND UNEMPLOYMENT RATE

# %%
gdp_df = pd.read_csv(r"/Users/odoms001/Downloads/IMA_Project/CS_Finance_Data/MacroEconomic_Variables/GDP.csv", parse_dates=True)
gdp_df['DATE'] = pd.to_datetime(gdp_df['DATE'])
print(gdp_df.shape)
gdp_df.head()
# Out:
# (81, 2)
#         DATE        GDP
# 0 2004-01-01  11923.447
# 1 2004-04-01  12112.815
# 2 2004-07-01  12305.307
# 3 2004-10-01  12527.214
# 4 2005-01-01  12767.286

# %%
uner_df = pd.read_csv(r"/Users/odoms001/Downloads/IMA_Project/CS_Finance_Data/MacroEconomic_Variables/UNRATE.csv")
uner_df['DATE'] = pd.to_datetime(uner_df['DATE'])
print(uner_df.shape)
uner_df.head()
# Out:
# (82, 2)
#         DATE    UNRATE
# 0 2004-01-01  5.700000
# 1 2004-04-01  5.600000
# 2 2004-07-01  5.433333
# 3 2004-10-01  5.433333
# 4 2005-01-01  5.300000

# %%
gdp_growth = pd.read_csv(r"/Users/odoms001/Downloads/IMA_Project/CS_Finance_Data/MacroEconomic_Variables/GDP_growth_2004-2024.csv")
gdp_growth['DATE'] = pd.to_datetime(gdp_growth['DATE'])
print(gdp_growth.shape)
gdp_growth.head()
# Out:
# (81, 2)
#         DATE   GDP growth
# 0 2004-01-01          2.3
# 1 2004-04-01          3.1
# 2 2004-07-01          3.8
# 3 2004-10-01          4.1
# 4 2005-01-01          4.5

# %%
# Combine GDP and Unemployment rate
df_gdp_uner = pd.merge(gdp_df, uner_df, on='DATE')
# print(df_gdp_uner.shape)
# df_gdp_uner.head()

# %%
# Combine with GDP growth
df_gdp_uner = pd.merge(gdp_growth, df_gdp_uner, on = 'DATE')
print(df_gdp_uner.shape)
df_gdp_uner.head()
# Out:
# (81, 4)
#         DATE   GDP growth        GDP    UNRATE
# 0 2004-01-01          2.3  11923.447  5.700000
# 1 2004-04-01          3.1  12112.815  5.600000
# 2 2004-07-01          3.8  12305.307  5.433333
# 3 2004-10-01          4.1  12527.214  5.433333
# 4 2005-01-01          4.5  12767.286  5.300000

# %%
df_gdp_uner.rename(columns={'DATE': 'date'}, inplace=True)

# %%
def update_quart_enddate_shift(df):
    # Define a dictionary to map the month to the new date
    quarter_end_dates = {1: (12, 31), 4: (3, 31), 7: (6, 30), 10: (9, 30)}

    # Apply the mapping to update the dates
    for month, (new_month, new_day) in quarter_end_dates.items():
        df.loc[df['date'].dt.month == month, 'date'] = df['date'].apply(
            lambda x: x.replace(month=new_month, day=new_day) if x.month == month else x
        )

    # offset the years by 1 for those whose month is december
    tmp_ids = df[df["date"].dt.month == 12].index
    df.loc[tmp_ids, "date"] = df.loc[tmp_ids, "date"] - pd.DateOffset(years=1)

    # drop the first row df_gdp_uner
    df.drop(df.index[0], inplace=True)
    df.reset_index(drop=True, inplace=True)

    return df

# %%
df_gdp_uner =  update_quart_enddate_shift(df_gdp_uner)
df_gdp_uner.head()
# Out:
#         date   GDP growth        GDP    UNRATE
# 0 2004-03-31          3.1  12112.815  5.600000
# 1 2004-06-30          3.8  12305.307  5.433333
# 2 2004-09-30          4.1  12527.214  5.433333
# 3 2004-12-31          4.5  12767.286  5.300000
# 4 2005-03-31          2.0  12922.656  5.100000

# %% [markdown]
# ### 2. US Department of Treasury Dataset -  Yield Curve Rates from 2004 - 2024

# %%
rates_df = pd.read_csv(r"/Users/odoms001/Downloads/IMA_Project/CS_Finance_Data/MacroEconomic_Variables/yield-curve-rates-2004-2024.csv", encoding='latin1')
rates_df.head()
# Out:
#          Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  \
# 0  07/15/2024  5.48  5.51  5.43  5.40  5.23  4.85  4.44  4.23  4.13  4.16
# 1  07/12/2024  5.47  5.52  5.43  5.41  5.23  4.87  4.45  4.22  4.10  4.13
# 2  07/11/2024  5.48  5.53  5.44  5.41  5.25  4.91  4.50  4.26  4.13  4.15
# 3  07/10/2024  5.46  5.50  5.46  5.46  5.33  5.01  4.62  4.38  4.24  4.24
# 4  07/09/2024  5.45  5.51  5.46  5.46  5.34  5.02  4.62  4.37  4.24  4.25
#
#    10 Yr  20 Yr  30 Yr
# 0   4.23   4.56   4.46
# 1   4.18   4.50   4.39
# 2   4.20   4.51   4.41
# 3   4.28   4.58   4.47
# 4   4.30   4.59   4.49

# %%
# Changing Date to Date-time Format
rates_df['Date'] = pd.to_datetime(rates_df['Date'].astype(str), utc = True)
rates_df.head()
# Out:
#                        Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  \
# 0 2024-07-15 00:00:00+00:00  5.48  5.51  5.43  5.40  5.23  4.85  4.44  4.23
# 1 2024-07-12 00:00:00+00:00  5.47  5.52  5.43  5.41  5.23  4.87  4.45  4.22
# 2 2024-07-11 00:00:00+00:00  5.48  5.53  5.44  5.41  5.25  4.91  4.50  4.26
# 3 2024-07-10 00:00:00+00:00  5.46  5.50  5.46  5.46  5.33  5.01  4.62  4.38
# 4 2024-07-09 00:00:00+00:00  5.45  5.51  5.46  5.46  5.34  5.02  4.62  4.37
#
#    5 Yr  7 Yr  10 Yr  20 Yr  30 Yr
# 0  4.13  4.16   4.23   4.56   4.46
# 1  4.10  4.13   4.18   4.50   4.39
# 2  4.13  4.15   4.20   4.51   4.41
# 3  4.24  4.24   4.28   4.58   4.47
# 4  4.24  4.25   4.30   4.59   4.49

# %%
# Giving the Year and Quarter each entry
rates_df['Year'] = rates_df['Date'].dt.year
rates_df['Quarter'] = rates_df['Date'].dt.quarter
rates_df.sort_values('Date').head()
# Out:
#                           Date  1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  \
# 5138 2004-01-02 00:00:00+00:00  0.88   NaN  0.93   NaN  1.02  1.31  1.94
# 5137 2004-01-05 00:00:00+00:00  0.88   NaN  0.91   NaN  1.05  1.35  1.95
# 5136 2004-01-06 00:00:00+00:00  0.88   NaN  0.91   NaN  1.03  1.30  1.84
# 5135 2004-01-07 00:00:00+00:00  0.88   NaN  0.91   NaN  1.02  1.29  1.84
# 5134 2004-01-08 00:00:00+00:00  0.87   NaN  0.88   NaN  1.01  1.29  1.85
#
#       3 Yr  5 Yr  7 Yr  10 Yr  20 Yr  30 Yr  Year  Quarter
# 5138  2.47  3.36  3.90   4.38   5.21    NaN  2004        1
# 5137  2.51  3.39  3.92   4.41   5.23    NaN  2004        1
# 5136  2.38  3.26  3.80   4.29   5.13    NaN  2004        1
# 5135  2.36  3.25  3.76   4.27   5.11    NaN  2004        1
# 5134  2.37  3.24  3.76   4.27   5.12    NaN  2004        1

# %%
finalrates = rates_df.groupby(['Year', 'Quarter']).mean()
finalrates.head(8)
# Out:
#                   1 Mo  2 Mo      3 Mo  4 Mo      6 Mo      1 Yr      2 Yr  \
# Year Quarter
# 2004 1        0.909677   NaN  0.933710   NaN  1.003548  1.221452  1.686613
#      2        0.954516   NaN  1.096129   NaN  1.359677  1.775484  2.454677
#      3        1.370000   NaN  1.513906   NaN  1.788437  2.075000  2.556563
#      4        1.841774   NaN  2.047419   NaN  2.297581  2.472742  2.822419
# 2005 1        2.360984   NaN  2.589180   NaN  2.876885  3.072459  3.454918
#      2        2.709687   NaN  2.926719   NaN  3.179688  3.337344  3.645938
#      3        3.228594   NaN  3.438281   NaN  3.707031  3.791094  3.957969
#      4        3.702131   NaN  3.913607   NaN  4.250492  4.288525  4.364590
#
#                   3 Yr      5 Yr      7 Yr     10 Yr     20 Yr  30 Yr
# Year Quarter
# 2004 1        2.163065  2.980968  3.501452  4.010000  4.877903    NaN
#      2        2.971935  3.720968  4.183871  4.597097  5.355645    NaN
#      3        2.919531  3.505625  3.922188  4.301406  5.068281    NaN
#      4        3.058871  3.493710  3.855000  4.175806  4.874839    NaN
# 2005 1        3.623934  3.890820  4.098852  4.303607  4.764098    NaN
#      2        3.732344  3.872969  3.984688  4.158594  4.548750    NaN
#      3        3.989219  4.039375  4.108437  4.215156  4.507656    NaN
#      4        4.372295  4.391148  4.425738  4.488197  4.767541    NaN

# %%
finalrates_df = finalrates.copy()
# finalrates = finalrates.drop(columns=["Date"], axis=1)
finalrates_df.reset_index(inplace=True)
finalrates_df.head()
# Out:
#    Year  Quarter      1 Mo  2 Mo      3 Mo  4 Mo      6 Mo      1 Yr  \
# 0  2004        1  0.909677   NaN  0.933710   NaN  1.003548  1.221452
# 1  2004        2  0.954516   NaN  1.096129   NaN  1.359677  1.775484
# 2  2004        3  1.370000   NaN  1.513906   NaN  1.788437  2.075000
# 3  2004        4  1.841774   NaN  2.047419   NaN  2.297581  2.472742
# 4  2005        1  2.360984   NaN  2.589180   NaN  2.876885  3.072459
#
#        2 Yr      3 Yr      5 Yr      7 Yr     10 Yr     20 Yr  30 Yr
# 0  1.686613  2.163065  2.980968  3.501452  4.010000  4.877903    NaN
# 1  2.454677  2.971935  3.720968  4.183871  4.597097  5.355645    NaN
# 2  2.556563  2.919531  3.505625  3.922188  4.301406  5.068281    NaN
# 3  2.822419  3.058871  3.493710  3.855000  4.175806  4.874839    NaN
# 4  3.454918  3.623934  3.890820  4.098852  4.303607  4.764098    NaN

# %% [markdown]
# ### 3. Spreads

# %%
#Second we modify the format, this is the solution that I found for the two digit year
def chain_date(date_str):
    for fmt in ('%m/%d/%Y', '%m/%d/%y'):
        try:
            return pd.to_datetime(date_str, format=fmt)
        except ValueError:
            pass
    return pd.NaT

# We apply the chain_date function
rates_df['Date'] = rates_df['Date'].apply(chain_date)


copy_df=rates_df.copy()

# %%
# Assign quarter
def assign_quarter(date):
    month = date.month
    if month in [1, 2, 3]:
        return '1'
    elif month in [4, 5, 6]:
        return '2'
    elif month in [7, 8, 9]:
        return '3'
    else:
        return '4'

# Asisign the quarters in a new column
copy_df['Quarter'] = copy_df['Date'].apply(assign_quarter)
copy_df['Year'] = copy_df['Date'].dt.year


# Agrupar por cuatrimestre y calcular el promedio de todas las columnas excepto 'Date'
quarterly_averages = copy_df.groupby(['Year', 'Quarter']).mean(numeric_only=True).reset_index()

# %%
#calculate the spreads for all the possible spreads (around 78 possible)
columns_to_consider = quarterly_averages.columns[2:]


column_pairs = list(itertools.combinations(columns_to_consider, 2))


#new data frame to store the spreads
spreads_df = pd.DataFrame()

for (col1, col2) in column_pairs:
    spread_col_name = f"{col2}-{col1}_spread"
    spreads_df[spread_col_name] = quarterly_averages[col2] - quarterly_averages[col1]


#Add the year-Quarter columns must have 80 columns in total
result_df = pd.concat([quarterly_averages.iloc[:, :2], spreads_df], axis=1)

result_df.head()
# Out:
#    Year Quarter  2 Mo-1 Mo_spread  3 Mo-1 Mo_spread  4 Mo-1 Mo_spread  \
# 0  2004       1               NaN          0.024032               NaN
# 1  2004       2               NaN          0.141613               NaN
# 2  2004       3               NaN          0.143906               NaN
# 3  2004       4               NaN          0.205645               NaN
# 4  2005       1               NaN          0.228197               NaN
#
#    6 Mo-1 Mo_spread  1 Yr-1 Mo_spread  2 Yr-1 Mo_spread  3 Yr-1 Mo_spread  \
# 0          0.093871          0.311774          0.776935          1.253387
# 1          0.405161          0.820968          1.500161          2.017419
# 2          0.418437          0.705000          1.186562          1.549531
# 3          0.455806          0.630968          0.980645          1.217097
# 4          0.515902          0.711475          1.093934          1.262951
#
#    5 Yr-1 Mo_spread  ...  7 Yr-5 Yr_spread  10 Yr-5 Yr_spread  \
# 0          2.071290  ...          0.520484           1.029032
# 1          2.766452  ...          0.462903           0.876129
# 2          2.135625  ...          0.416562           0.795781
# 3          1.651935  ...          0.361290           0.682097
# 4          1.529836  ...          0.208033           0.412787
#
#    20 Yr-5 Yr_spread  30 Yr-5 Yr_spread  10 Yr-7 Yr_spread  20 Yr-7 Yr_spread  \
# 0           1.896935                NaN           0.508548           1.376452
# 1           1.634677                NaN           0.413226           1.171774
# 2           1.562656                NaN           0.379219           1.146094
# 3           1.381129                NaN           0.320806           1.019839
# 4           0.873279                NaN           0.204754           0.665246
#
#    30 Yr-7 Yr_spread  20 Yr-10 Yr_spread  30 Yr-10 Yr_spread  \
# 0                NaN            0.867903                 NaN
# 1                NaN            0.758548                 NaN
# 2                NaN            0.766875                 NaN
# 3                NaN            0.699032                 NaN
# 4                NaN            0.460492                 NaN
#
#    30 Yr-20 Yr_spread
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 80 columns]

# %%
Spreads_df = result_df.copy()
Spreads_df.drop(columns=["Year", "Quarter"], inplace=True)
Spreads_df.head()
# Out:
#    2 Mo-1 Mo_spread  3 Mo-1 Mo_spread  4 Mo-1 Mo_spread  6 Mo-1 Mo_spread  \
# 0               NaN          0.024032               NaN          0.093871
# 1               NaN          0.141613               NaN          0.405161
# 2               NaN          0.143906               NaN          0.418437
# 3               NaN          0.205645               NaN          0.455806
# 4               NaN          0.228197               NaN          0.515902
#
#    1 Yr-1 Mo_spread  2 Yr-1 Mo_spread  3 Yr-1 Mo_spread  5 Yr-1 Mo_spread  \
# 0          0.311774          0.776935          1.253387          2.071290
# 1          0.820968          1.500161          2.017419          2.766452
# 2          0.705000          1.186562          1.549531          2.135625
# 3          0.630968          0.980645          1.217097          1.651935
# 4          0.711475          1.093934          1.262951          1.529836
#
#    7 Yr-1 Mo_spread  10 Yr-1 Mo_spread  ...  7 Yr-5 Yr_spread  \
# 0          2.591774           3.100323  ...          0.520484
# 1          3.229355           3.642581  ...          0.462903
# 2          2.552188           2.931406  ...          0.416562
# 3          2.013226           2.334032  ...          0.361290
# 4          1.737869           1.942623  ...          0.208033
#
#    10 Yr-5 Yr_spread  20 Yr-5 Yr_spread  30 Yr-5 Yr_spread  10 Yr-7 Yr_spread  \
# 0           1.029032           1.896935                NaN           0.508548
# 1           0.876129           1.634677                NaN           0.413226
# 2           0.795781           1.562656                NaN           0.379219
# 3           0.682097           1.381129                NaN           0.320806
# 4           0.412787           0.873279                NaN           0.204754
#
#    20 Yr-7 Yr_spread  30 Yr-7 Yr_spread  20 Yr-10 Yr_spread  \
# 0           1.376452                NaN            0.867903
# 1           1.171774                NaN            0.758548
# 2           1.146094                NaN            0.766875
# 3           1.019839                NaN            0.699032
# 4           0.665246                NaN            0.460492
#
#    30 Yr-10 Yr_spread  30 Yr-20 Yr_spread
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN
#
# [5 rows x 78 columns]

# %% [markdown]
# ### Combine macroeconomic variables

# %%
# Combine Interest Rate, Spreads, GDP, GDP Growth and Unemployment Rates
cmev = pd.concat([finalrates_df, Spreads_df, df_gdp_uner], axis = 1)
cmev.drop(columns=['Year', 'Quarter'], inplace=True)
cmev.head()
# Out:
#        1 Mo  2 Mo      3 Mo  4 Mo      6 Mo      1 Yr      2 Yr      3 Yr  \
# 0  0.909677   NaN  0.933710   NaN  1.003548  1.221452  1.686613  2.163065
# 1  0.954516   NaN  1.096129   NaN  1.359677  1.775484  2.454677  2.971935
# 2  1.370000   NaN  1.513906   NaN  1.788437  2.075000  2.556563  2.919531
# 3  1.841774   NaN  2.047419   NaN  2.297581  2.472742  2.822419  3.058871
# 4  2.360984   NaN  2.589180   NaN  2.876885  3.072459  3.454918  3.623934
#
#        5 Yr      7 Yr  ...  10 Yr-7 Yr_spread  20 Yr-7 Yr_spread  \
# 0  2.980968  3.501452  ...           0.508548           1.376452
# 1  3.720968  4.183871  ...           0.413226           1.171774
# 2  3.505625  3.922188  ...           0.379219           1.146094
# 3  3.493710  3.855000  ...           0.320806           1.019839
# 4  3.890820  4.098852  ...           0.204754           0.665246
#
#    30 Yr-7 Yr_spread  20 Yr-10 Yr_spread  30 Yr-10 Yr_spread  \
# 0                NaN            0.867903                 NaN
# 1                NaN            0.758548                 NaN
# 2                NaN            0.766875                 NaN
# 3                NaN            0.699032                 NaN
# 4                NaN            0.460492                 NaN
#
#    30 Yr-20 Yr_spread       date   GDP growth        GDP    UNRATE
# 0                 NaN 2004-03-31          3.1  12112.815  5.600000
# 1                 NaN 2004-06-30          3.8  12305.307  5.433333
# 2                 NaN 2004-09-30          4.1  12527.214  5.433333
# 3                 NaN 2004-12-31          4.5  12767.286  5.300000
# 4                 NaN 2005-03-31          2.0  12922.656  5.100000
#
# [5 rows x 95 columns]

# %%
cmev.shape
# Out:
# (83, 95)

# %% [markdown]
# ### Combine Financial data with Macroeconomic Variables

# %%
Quarterized_dfs.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code  Bank Count  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9        11.0
# 1  1020180  BREMER FINANCIAL CORPORATION                 9        11.0
# 2  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
# 3  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
# 4  1020180  BREMER FINANCIAL CORPORATION                 9        10.0
#
#   Reporting Date  Interest Income  Total Assets  Quarter  Year  \
# 0     2004-03-31          68233.0     5721282.0        1  2004
# 1     2004-06-30         138086.0     5870480.0        2  2004
# 2     2004-09-30         212489.0     5963700.0        3  2004
# 3     2004-12-31         291916.0     6141519.0        4  2004
# 4     2005-03-31          81656.0     6230236.0        1  2005
#
#    QInterest Income  Normalized Interest Income per Quarter
# 0           68233.0                                0.011926
# 1           69853.0                                0.011899
# 2           74403.0                                0.012476
# 3           79427.0                                0.012933
# 4           81656.0                                0.013106

# %%
Quarterized_dfs.shape
# Out:
# (243757, 11)

# %%
# selecting some columns of Quarter
small_Quaterized_dfs = Quarterized_dfs[['RSSD ID', 'Firm Legal Name', 'FR District Code', 'Reporting Date', "Total Assets", 'Year', 'Quarter',
                                         'Normalized Interest Income per Quarter']]

small_Quaterized_dfs.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code Reporting Date  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9     2004-03-31
# 1  1020180  BREMER FINANCIAL CORPORATION                 9     2004-06-30
# 2  1020180  BREMER FINANCIAL CORPORATION                 9     2004-09-30
# 3  1020180  BREMER FINANCIAL CORPORATION                 9     2004-12-31
# 4  1020180  BREMER FINANCIAL CORPORATION                 9     2005-03-31
#
#    Total Assets  Year  Quarter  Normalized Interest Income per Quarter
# 0     5721282.0  2004        1                                0.011926
# 1     5870480.0  2004        2                                0.011899
# 2     5963700.0  2004        3                                0.012476
# 3     6141519.0  2004        4                                0.012933
# 4     6230236.0  2005        1                                0.013106

# %%
# Merge the DataFrames
df = small_Quaterized_dfs.merge(cmev, left_on='Reporting Date', right_on='date', how='left')
df.drop(columns=['date'], inplace=True)
df.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code Reporting Date  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9     2004-03-31
# 1  1020180  BREMER FINANCIAL CORPORATION                 9     2004-06-30
# 2  1020180  BREMER FINANCIAL CORPORATION                 9     2004-09-30
# 3  1020180  BREMER FINANCIAL CORPORATION                 9     2004-12-31
# 4  1020180  BREMER FINANCIAL CORPORATION                 9     2005-03-31
#
#    Total Assets  Year  Quarter  Normalized Interest Income per Quarter  \
# 0     5721282.0  2004        1                                0.011926
# 1     5870480.0  2004        2                                0.011899
# 2     5963700.0  2004        3                                0.012476
# 3     6141519.0  2004        4                                0.012933
# 4     6230236.0  2005        1                                0.013106
#
#        1 Mo  2 Mo  ...  30 Yr-5 Yr_spread  10 Yr-7 Yr_spread  \
# 0  0.909677   NaN  ...                NaN           0.508548
# 1  0.954516   NaN  ...                NaN           0.413226
# 2  1.370000   NaN  ...                NaN           0.379219
# 3  1.841774   NaN  ...                NaN           0.320806
# 4  2.360984   NaN  ...                NaN           0.204754
#
#    20 Yr-7 Yr_spread  30 Yr-7 Yr_spread  20 Yr-10 Yr_spread  \
# 0           1.376452                NaN            0.867903
# 1           1.171774                NaN            0.758548
# 2           1.146094                NaN            0.766875
# 3           1.019839                NaN            0.699032
# 4           0.665246                NaN            0.460492
#
#    30 Yr-10 Yr_spread  30 Yr-20 Yr_spread   GDP growth        GDP    UNRATE
# 0                 NaN                 NaN          3.1  12112.815  5.600000
# 1                 NaN                 NaN          3.8  12305.307  5.433333
# 2                 NaN                 NaN          4.1  12527.214  5.433333
# 3                 NaN                 NaN          4.5  12767.286  5.300000
# 4                 NaN                 NaN          2.0  12922.656  5.100000
#
# [5 rows x 102 columns]

# %%
df.shape
# Out:
# (243757, 102)

# %%
#pd.set_option('display.max_rows', None)
df.isnull().sum().sort_values()
# Out:
# RSSD ID                   0
# Firm Legal Name           0
# FR District Code          0
# Reporting Date            0
# Year                      0
#                       ...
# 7 Yr-4 Mo_spread     231244
# 10 Yr-4 Mo_spread    231244
# 20 Yr-4 Mo_spread    231244
# 30 Yr-4 Mo_spread    231244
# 4 Mo-3 Mo_spread     231244
# Length: 102, dtype: int64

# %%
# Extract the 'Normalized Interest Income per Quarter' column
normalized_income = df['Normalized Interest Income per Quarter']

# Fill missing values with the mean of the column for income
normalized_income_filled = normalized_income.fillna(normalized_income.mean())

# Update the original DataFrame
df['Normalized Interest Income per Quarter'] = normalized_income_filled

# %%
# Display the number of missing values per column
missing_values = df.isnull().sum()

# Sort the columns by the number of missing values (ascending order)
sorted_missing_values = missing_values.sort_values()

# Filter the DataFrame to include only columns with fewer missing values (e.g., less than a threshold)
# Set a threshold for maximum allowed missing values (e.g., 500)
threshold = 500
filtered_columns = sorted_missing_values[sorted_missing_values <= threshold].index

# Create a new DataFrame with the filtered columns
df0 = df[filtered_columns].dropna()
df0.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code Reporting Date  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9     2004-03-31
# 1  1020180  BREMER FINANCIAL CORPORATION                 9     2004-06-30
# 2  1020180  BREMER FINANCIAL CORPORATION                 9     2004-09-30
# 3  1020180  BREMER FINANCIAL CORPORATION                 9     2004-12-31
# 4  1020180  BREMER FINANCIAL CORPORATION                 9     2005-03-31
#
#    Year  Quarter  Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 0  2004        1                                0.011926          0.941613
# 1  2004        2                                0.011899          1.196452
# 2  2004        3                                0.012476          0.844531
# 3  2004        4                                0.012933          0.586129
# 4  2005        1                                0.013106          0.551475
#
#    2 Yr-1 Yr_spread  20 Yr-6 Mo_spread  ...      5 Yr      3 Yr      2 Yr  \
# 0          0.465161           3.874355  ...  2.980968  2.163065  1.686613
# 1          0.679194           3.995968  ...  3.720968  2.971935  2.454677
# 2          0.481562           3.279844  ...  3.505625  2.919531  2.556563
# 3          0.349677           2.577258  ...  3.493710  3.058871  2.822419
# 4          0.382459           1.887213  ...  3.890820  3.623934  3.454918
#
#        1 Yr      6 Mo      3 Mo      1 Mo      7 Yr  20 Yr-1 Mo_spread  \
# 0  1.221452  1.003548  0.933710  0.909677  3.501452           3.968226
# 1  1.775484  1.359677  1.096129  0.954516  4.183871           4.401129
# 2  2.075000  1.788437  1.513906  1.370000  3.922188           3.698281
# 3  2.472742  2.297581  2.047419  1.841774  3.855000           3.033065
# 4  3.072459  2.876885  2.589180  2.360984  4.098852           2.403115
#
#      UNRATE
# 0  5.600000
# 1  5.433333
# 2  5.433333
# 3  5.300000
# 4  5.100000
#
# [5 rows x 65 columns]

# %%
df0.isnull().sum()
# Out:
# RSSD ID              0
# Firm Legal Name      0
# FR District Code     0
# Reporting Date       0
# Year                 0
#                     ..
# 3 Mo                 0
# 1 Mo                 0
# 7 Yr                 0
# 20 Yr-1 Mo_spread    0
# UNRATE               0
# Length: 65, dtype: int64

# %%
# Making Lagged Variable for Normalized Interest Income
new_dfs = []
for i in df0['RSSD ID'].unique():
    new_df_i = df0.loc[df0['RSSD ID']==i,:]
    new_df_i = new_df_i.sort_values(['Year', 'Quarter'])
    new_df_i["Lagged Income"] = new_df_i['Normalized Interest Income per Quarter'].shift(1)
    new_dfs.append(new_df_i)

df_lag = pd.concat(new_dfs, ignore_index=True)
df_lag.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code Reporting Date  \
# 0  1020180  BREMER FINANCIAL CORPORATION                 9     2004-03-31
# 1  1020180  BREMER FINANCIAL CORPORATION                 9     2004-06-30
# 2  1020180  BREMER FINANCIAL CORPORATION                 9     2004-09-30
# 3  1020180  BREMER FINANCIAL CORPORATION                 9     2004-12-31
# 4  1020180  BREMER FINANCIAL CORPORATION                 9     2005-03-31
#
#    Year  Quarter  Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 0  2004        1                                0.011926          0.941613
# 1  2004        2                                0.011899          1.196452
# 2  2004        3                                0.012476          0.844531
# 3  2004        4                                0.012933          0.586129
# 4  2005        1                                0.013106          0.551475
#
#    2 Yr-1 Yr_spread  20 Yr-6 Mo_spread  ...      3 Yr      2 Yr      1 Yr  \
# 0          0.465161           3.874355  ...  2.163065  1.686613  1.221452
# 1          0.679194           3.995968  ...  2.971935  2.454677  1.775484
# 2          0.481562           3.279844  ...  2.919531  2.556563  2.075000
# 3          0.349677           2.577258  ...  3.058871  2.822419  2.472742
# 4          0.382459           1.887213  ...  3.623934  3.454918  3.072459
#
#        6 Mo      3 Mo      1 Mo      7 Yr  20 Yr-1 Mo_spread    UNRATE  \
# 0  1.003548  0.933710  0.909677  3.501452           3.968226  5.600000
# 1  1.359677  1.096129  0.954516  4.183871           4.401129  5.433333
# 2  1.788437  1.513906  1.370000  3.922188           3.698281  5.433333
# 3  2.297581  2.047419  1.841774  3.855000           3.033065  5.300000
# 4  2.876885  2.589180  2.360984  4.098852           2.403115  5.100000
#
#    Lagged Income
# 0            NaN
# 1       0.011926
# 2       0.011899
# 3       0.012476
# 4       0.012933
#
# [5 rows x 66 columns]

# %%
df_lag.isnull().sum()
# Out:
# RSSD ID                 0
# Firm Legal Name         0
# FR District Code        0
# Reporting Date          0
# Year                    0
#                      ...
# 1 Mo                    0
# 7 Yr                    0
# 20 Yr-1 Mo_spread       0
# UNRATE                  0
# Lagged Income        8048
# Length: 66, dtype: int64

# %%
df_lag = df_lag.dropna()
df_lag.head()
# Out:
#    RSSD ID               Firm Legal Name  FR District Code Reporting Date  \
# 1  1020180  BREMER FINANCIAL CORPORATION                 9     2004-06-30
# 2  1020180  BREMER FINANCIAL CORPORATION                 9     2004-09-30
# 3  1020180  BREMER FINANCIAL CORPORATION                 9     2004-12-31
# 4  1020180  BREMER FINANCIAL CORPORATION                 9     2005-03-31
# 5  1020180  BREMER FINANCIAL CORPORATION                 9     2005-06-30
#
#    Year  Quarter  Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 1  2004        2                                0.011899          1.196452
# 2  2004        3                                0.012476          0.844531
# 3  2004        4                                0.012933          0.586129
# 4  2005        1                                0.013106          0.551475
# 5  2005        2                                0.013722          0.395000
#
#    2 Yr-1 Yr_spread  20 Yr-6 Mo_spread  ...      3 Yr      2 Yr      1 Yr  \
# 1          0.679194           3.995968  ...  2.971935  2.454677  1.775484
# 2          0.481562           3.279844  ...  2.919531  2.556563  2.075000
# 3          0.349677           2.577258  ...  3.058871  2.822419  2.472742
# 4          0.382459           1.887213  ...  3.623934  3.454918  3.072459
# 5          0.308594           1.369063  ...  3.732344  3.645938  3.337344
#
#        6 Mo      3 Mo      1 Mo      7 Yr  20 Yr-1 Mo_spread    UNRATE  \
# 1  1.359677  1.096129  0.954516  4.183871           4.401129  5.433333
# 2  1.788437  1.513906  1.370000  3.922188           3.698281  5.433333
# 3  2.297581  2.047419  1.841774  3.855000           3.033065  5.300000
# 4  2.876885  2.589180  2.360984  4.098852           2.403115  5.100000
# 5  3.179688  2.926719  2.709687  3.984688           1.839063  4.966667
#
#    Lagged Income
# 1       0.011926
# 2       0.011899
# 3       0.012476
# 4       0.012933
# 5       0.013106
#
# [5 rows x 66 columns]

# %%
df_lag.shape
# Out:
# (235236, 66)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Data Preparation

# %%
df2 = df.dropna(subset = ['Total Assets'])
df2 = df2.sort_values(by = ['Total Assets'])

# %%
# Display the number of missing values per column
missing_values = df2.isnull().sum()

# Sort the columns by the number of missing values (ascending order)
sorted_missing_values = missing_values.sort_values()

# Filter the DataFrame to include only columns with fewer missing values (e.g., less than a threshold)
# Set a threshold for maximum allowed missing values (e.g., 500)
threshold = 500
filtered_columns = sorted_missing_values[sorted_missing_values <= threshold].index

# Create a new DataFrame with the filtered columns
df2 = df2[filtered_columns].dropna()

# %%
df2.shape
# Out:
# (73456, 66)

# %%
# Making Lagged Variable for Normalized Interest Income
new_dfs = []

# Iterate over unique quarters
for i in df2['RSSD ID'].unique():
    new_df_i = df2.loc[df2['RSSD ID']==i,:]
    new_df_i = new_df_i.sort_values(['Year', 'Quarter'])
    new_df_i["Lagged Income"] = new_df_i['Normalized Interest Income per Quarter'].shift(1)
    new_dfs.append(new_df_i)

df3 = pd.concat(new_dfs, ignore_index=True)

# %%
# Making a large bank variable

new_dfs = []

# Iterate over unique quarters
for quarter in df3['Quarter'].unique():
    new_df_quarter = df3[df3['Quarter'] == quarter]
    
    # Iterate over unique years within each quarter
    for year in new_df_quarter['Year'].unique():
        new_df_quarter_year = new_df_quarter[new_df_quarter['Year'] == year].copy()
        
        # Calculate mean total assets for the current slice and create 'Large Bank' variable
        mean_assets = new_df_quarter_year['Total Assets'].mean()
        new_df_quarter_year['Large Bank'] = new_df_quarter_year['Total Assets'] > mean_assets
        
        # Append the processed slice to the list
        new_dfs.append(new_df_quarter_year)

# Concatenate all processed slices into a single DataFrame
df4 = pd.concat(new_dfs, ignore_index=True)

# Display the head of the final DataFrame
df4.head()
# Out:
#    RSSD ID                 Firm Legal Name  FR District Code Reporting Date  \
# 0  1247334            CAPITOL BANCORP LTD.                 7     2004-03-31
# 1  2595939  BUILDERS FINANCIAL CORPORATION                 7     2004-03-31
# 2  2322304           FIRST MARINER BANCORP                 5     2004-03-31
# 3  1056125                 CHAMBANCO, INC.                10     2004-03-31
# 4  1839270      SURETY CAPITAL CORPORATION                11     2004-03-31
#
#    Total Assets  Year  Quarter  Normalized Interest Income per Quarter  \
# 0     2867800.0  2004        1                                0.014453
# 1      407516.0  2004        1                                0.013607
# 2     1092393.0  2004        1                                0.013859
# 3       41898.0  2004        1                                0.013581
# 4       62276.0  2004        1                                0.016266
#
#    3 Yr-1 Yr_spread  2 Yr-1 Yr_spread  ...      2 Yr      1 Yr      6 Mo  \
# 0          0.941613          0.465161  ...  1.686613  1.221452  1.003548
# 1          0.941613          0.465161  ...  1.686613  1.221452  1.003548
# 2          0.941613          0.465161  ...  1.686613  1.221452  1.003548
# 3          0.941613          0.465161  ...  1.686613  1.221452  1.003548
# 4          0.941613          0.465161  ...  1.686613  1.221452  1.003548
#
#       3 Mo      1 Mo      7 Yr  20 Yr-1 Mo_spread  UNRATE  Lagged Income  \
# 0  0.93371  0.909677  3.501452           3.968226     5.6            NaN
# 1  0.93371  0.909677  3.501452           3.968226     5.6            NaN
# 2  0.93371  0.909677  3.501452           3.968226     5.6            NaN
# 3  0.93371  0.909677  3.501452           3.968226     5.6            NaN
# 4  0.93371  0.909677  3.501452           3.968226     5.6            NaN
#
#    Large Bank
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#
# [5 rows x 68 columns]

# %%
df4.shape
# Out:
# (73456, 68)

# %%
# Drop NA values
df4 = df4.dropna()

# %% [markdown]
# ### 1. Linear Regression

# %%
# Fitting model without Lagged Income

X= df4[['3 Mo', '1 Yr', '3 Yr', '10 Yr', 'UNRATE', 'GDP']]  # Predictors 

y= df4['Normalized Interest Income per Quarter'] #  Target variable

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
print(f'Coefficients: {model.coef_}')
print(f'Intercept: {model.intercept_}')
# Out:
# Mean Squared Error: 7.1446395408413375e-06
# R² Score: 0.4394436977428994
# Coefficients: [ 0.00022006  0.00314936 -0.00222526  0.00108575  0.00036732 -0.00087176]
# Intercept: 0.011686679285131242

# %%
## Fitting a model w Lagged Income variable:

X= df4[['3 Mo', '1 Yr', '3 Yr', '10 Yr', 'Lagged Income', 'UNRATE', 'GDP']]  # variables

y= df4['Normalized Interest Income per Quarter'] #Independent variable PPNR

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Create a linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
print(f'Coefficients: {model.coef_}')
print(f'Intercept: {model.intercept_}')
# Out:
# Mean Squared Error: 1.8085510226736255e-06
# R² Score: 0.8581041537619905
# Coefficients: [ 6.35196069e-05  1.13624740e-03 -5.32731854e-04  3.71477070e-04
#   2.38305839e-03  1.08255917e-04 -3.29285341e-04]
# Intercept: 0.011683001216268332

# %% [markdown]
# ### 2. Random forest

# %%
# with scaling but without lagged income

X= df4[['3 Mo', '1 Yr', '3 Yr','10 Yr', 'UNRATE', 'GDP']]  # variables

y= df4['Normalized Interest Income per Quarter'] #Independent variable PPNR

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Create a Random Forest Regressor model
rf = RandomForestRegressor(max_features=4, random_state=42)

# Train the model
rf.fit(X_train, y_train)

# Make predictions
y_pred = rf.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 6.939127535222356e-06
# R² Score: 0.45556782118967176

# %%
# with scaling and with lagged income

X= df4[['3 Mo', '1 Yr', '3 Yr','10 Yr', 'Lagged Income', 'UNRATE', 'GDP']]  # variables

y= df4['Normalized Interest Income per Quarter'] #Independent variable PPNR

scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Create a Random Forest Regressor model
rf = RandomForestRegressor(max_features=3, random_state=42)

# Train the model
rf.fit(X_train, y_train)

# Make predictions
y_pred = rf.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 1.655157693870323e-06
# R² Score: 0.8701391342103899

# %% [markdown]
# Tuning the parameter max_features (1, 2, ..., 7) by cross validation, we obtained that 3 gave the best $R^2$ so used that.

# %% [markdown]
# ### Comparing different Models

# %%
df4.head()
# Out:
#       RSSD ID                 Firm Legal Name  FR District Code  \
# 2241  1247334            CAPITOL BANCORP LTD.                 7
# 2242  2856014        LEADERS GROUP, INC., THE                 7
# 2243  2595939  BUILDERS FINANCIAL CORPORATION                 7
# 2244  2322304           FIRST MARINER BANCORP                 5
# 2245  1056125                 CHAMBANCO, INC.                10
#
#      Reporting Date  Total Assets  Year  Quarter  \
# 2241     2005-03-31     3215193.0  2005        1
# 2242     2005-03-31      248562.0  2005        1
# 2243     2005-03-31      408046.0  2005        1
# 2244     2005-03-31     1278404.0  2005        1
# 2245     2005-03-31       39374.0  2005        1
#
#       Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 2241                                0.015527          0.551475
# 2242                                0.012926          0.551475
# 2243                                0.016682          0.551475
# 2244                                0.014204          0.551475
# 2245                                0.013664          0.551475
#
#       2 Yr-1 Yr_spread  ...      2 Yr      1 Yr      6 Mo     3 Mo      1 Mo  \
# 2241          0.382459  ...  3.454918  3.072459  2.876885  2.58918  2.360984
# 2242          0.382459  ...  3.454918  3.072459  2.876885  2.58918  2.360984
# 2243          0.382459  ...  3.454918  3.072459  2.876885  2.58918  2.360984
# 2244          0.382459  ...  3.454918  3.072459  2.876885  2.58918  2.360984
# 2245          0.382459  ...  3.454918  3.072459  2.876885  2.58918  2.360984
#
#           7 Yr  20 Yr-1 Mo_spread  UNRATE  Lagged Income  Large Bank
# 2241  4.098852           2.403115     5.1       0.015633       False
# 2242  4.098852           2.403115     5.1       0.011675       False
# 2243  4.098852           2.403115     5.1       0.015707       False
# 2244  4.098852           2.403115     5.1       0.014048       False
# 2245  4.098852           2.403115     5.1       0.013040       False
#
# [5 rows x 68 columns]

# %%
mc_df = df4.copy()
mc_df.reset_index(drop=True, inplace=True)
# mc_df.head()

# %%
# Use the data up to 2022 as training 
data_train = mc_df[mc_df["Year"] <= 2022]
# data_train.head()

# %%
# After 2022 as our Testing Set
data_test = mc_df[mc_df["Year"] > 2022]
data_test.head()
# Out:
#        RSSD ID                       Firm Legal Name  FR District Code  \
# 15704  5478903                             CSBH, LLC                 5
# 15705  1142309  MIDWEST INDEPENDENT BANCSHARES, INC.                 8
# 15706  2385493           FIRST BANCSHARES, INC., THE                 6
# 15707  2737814          NORTHPOINTE BANCSHARES, INC.                 7
# 15708  1131497                  SMARTFINANCIAL, INC.                 6
#
#       Reporting Date  Total Assets  Year  Quarter  \
# 15704     2023-03-31      141756.0  2023        1
# 15705     2023-03-31      321513.0  2023        1
# 15706     2023-03-31     8016466.0  2023        1
# 15707     2023-03-31     4554982.0  2023        1
# 15708     2023-03-31     4769805.0  2023        1
#
#        Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 15704                                0.010250         -0.684032
# 15705                                0.011381         -0.684032
# 15706                                0.010022         -0.684032
# 15707                                0.012713         -0.684032
# 15708                                0.011149         -0.684032
#
#        2 Yr-1 Yr_spread  ...      2 Yr      1 Yr      6 Mo      3 Mo  \
# 15704         -0.416613  ...  4.342742  4.759355  4.923548  4.781774
# 15705         -0.416613  ...  4.342742  4.759355  4.923548  4.781774
# 15706         -0.416613  ...  4.342742  4.759355  4.923548  4.781774
# 15707         -0.416613  ...  4.342742  4.759355  4.923548  4.781774
# 15708         -0.416613  ...  4.342742  4.759355  4.923548  4.781774
#
#            1 Mo      7 Yr  20 Yr-1 Mo_spread    UNRATE  Lagged Income  \
# 15704  4.546613  3.740484          -0.646774  3.566667       0.010513
# 15705  4.546613  3.740484          -0.646774  3.566667       0.009479
# 15706  4.546613  3.740484          -0.646774  3.566667       0.008953
# 15707  4.546613  3.740484          -0.646774  3.566667       0.011702
# 15708  4.546613  3.740484          -0.646774  3.566667       0.010202
#
#        Large Bank
# 15704       False
# 15705       False
# 15706       False
# 15707       False
# 15708       False
#
# [5 rows x 68 columns]

# %%
# Fit a linear regression including lagged Income

X_train = data_train[['3 Mo', '1 Yr', '3 Yr', '10 Yr', 'Lagged Income', 'UNRATE', 'GDP']]

y_train= data_train['Normalized Interest Income per Quarter'] #Independent variable PPNR

X_test = data_test[['3 Mo', '1 Yr', '3 Yr', '10 Yr', 'Lagged Income', 'UNRATE', 'GDP']]

y_test = data_test['Normalized Interest Income per Quarter'] #Independent variable PPNR


# Create a linear regression model
lrm = LinearRegression()

# Train the model
lrm.fit(X_train, y_train)

# Make predictions
y_pred = lrm.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
print(f'Coefficients: {lrm.coef_}')
print(f'Intercept: {lrm.intercept_}')
# Out:
# Mean Squared Error: 3.7765205734508944e-06
# R² Score: 0.7664548966944998
# Coefficients: [ 4.33730624e-05  6.03203399e-04 -3.15517372e-04  3.36314428e-04
#   6.14066803e-01  5.46808743e-05 -7.59980587e-08]
# Intercept: 0.003907792981403585

# %%
data_test['PredRate_lrm']=y_pred
data_test['Pred_Q_Income_lrm'] =  data_test['PredRate_lrm'] * data_test['Total Assets']
data_test.head()
# Out:
#        RSSD ID                       Firm Legal Name  FR District Code  \
# 15704  5478903                             CSBH, LLC                 5
# 15705  1142309  MIDWEST INDEPENDENT BANCSHARES, INC.                 8
# 15706  2385493           FIRST BANCSHARES, INC., THE                 6
# 15707  2737814          NORTHPOINTE BANCSHARES, INC.                 7
# 15708  1131497                  SMARTFINANCIAL, INC.                 6
#
#       Reporting Date  Total Assets  Year  Quarter  \
# 15704     2023-03-31      141756.0  2023        1
# 15705     2023-03-31      321513.0  2023        1
# 15706     2023-03-31     8016466.0  2023        1
# 15707     2023-03-31     4554982.0  2023        1
# 15708     2023-03-31     4769805.0  2023        1
#
#        Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 15704                                0.010250         -0.684032
# 15705                                0.011381         -0.684032
# 15706                                0.010022         -0.684032
# 15707                                0.012713         -0.684032
# 15708                                0.011149         -0.684032
#
#        2 Yr-1 Yr_spread  ...      6 Mo      3 Mo      1 Mo      7 Yr  \
# 15704         -0.416613  ...  4.923548  4.781774  4.546613  3.740484
# 15705         -0.416613  ...  4.923548  4.781774  4.546613  3.740484
# 15706         -0.416613  ...  4.923548  4.781774  4.546613  3.740484
# 15707         -0.416613  ...  4.923548  4.781774  4.546613  3.740484
# 15708         -0.416613  ...  4.923548  4.781774  4.546613  3.740484
#
#        20 Yr-1 Mo_spread    UNRATE  Lagged Income  Large Bank  PredRate_lrm  \
# 15704          -0.646774  3.566667       0.010513       False      0.011520
# 15705          -0.646774  3.566667       0.009479       False      0.010886
# 15706          -0.646774  3.566667       0.008953       False      0.010563
# 15707          -0.646774  3.566667       0.011702       False      0.012250
# 15708          -0.646774  3.566667       0.010202       False      0.011330
#
#        Pred_Q_Income_lrm
# 15704        1633.091474
# 15705        3499.849823
# 15706       84674.599805
# 15707       55800.173636
# 15708       54041.013398
#
# [5 rows x 70 columns]

# %%
# large 5 banks
rssd_id_5 = [1039502, 1073757, 1951350, 2380443, 2162966]

# %%
# tmp_df = data_test.set_index("RSSD ID")
# df5 = tmp_df.loc[rssd_id_5]
# df5.reset_index(inplace=True)
# df5.head()

# %% [markdown]
# **Repeat for the Random forest model**

# %%
# Random forest
X_train = data_train[['3 Mo', '1 Yr', '3 Yr', '10 Yr', 'Lagged Income', 'UNRATE', 'GDP']]

y_train= data_train['Normalized Interest Income per Quarter'] #Independent variable PPNR

X_test = data_test[['3 Mo', '1 Yr', '3 Yr', '10 Yr', 'Lagged Income', 'UNRATE', 'GDP']]

y_test = data_test['Normalized Interest Income per Quarter'] #Independent variable PPNR

# Create a Random Forest Regressor model
rf = RandomForestRegressor(max_features=3, random_state=42)

# Train the model
rf.fit(X_train, y_train)

# Make predictions
y_predRf = rf.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_predRf)
r2 = r2_score(y_test, y_predRf)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 2.7020625994512554e-06
# R² Score: 0.8329008205693078

# %%
data_test['PredRate_rf']=y_predRf
data_test['Pred_Q_Income_rf'] =  data_test['PredRate_rf'] * data_test['Total Assets']
data_test.head()
# Out:
#        RSSD ID                       Firm Legal Name  FR District Code  \
# 15704  5478903                             CSBH, LLC                 5
# 15705  1142309  MIDWEST INDEPENDENT BANCSHARES, INC.                 8
# 15706  2385493           FIRST BANCSHARES, INC., THE                 6
# 15707  2737814          NORTHPOINTE BANCSHARES, INC.                 7
# 15708  1131497                  SMARTFINANCIAL, INC.                 6
#
#       Reporting Date  Total Assets  Year  Quarter  \
# 15704     2023-03-31      141756.0  2023        1
# 15705     2023-03-31      321513.0  2023        1
# 15706     2023-03-31     8016466.0  2023        1
# 15707     2023-03-31     4554982.0  2023        1
# 15708     2023-03-31     4769805.0  2023        1
#
#        Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 15704                                0.010250         -0.684032
# 15705                                0.011381         -0.684032
# 15706                                0.010022         -0.684032
# 15707                                0.012713         -0.684032
# 15708                                0.011149         -0.684032
#
#        2 Yr-1 Yr_spread  ...      1 Mo      7 Yr  20 Yr-1 Mo_spread    UNRATE  \
# 15704         -0.416613  ...  4.546613  3.740484          -0.646774  3.566667
# 15705         -0.416613  ...  4.546613  3.740484          -0.646774  3.566667
# 15706         -0.416613  ...  4.546613  3.740484          -0.646774  3.566667
# 15707         -0.416613  ...  4.546613  3.740484          -0.646774  3.566667
# 15708         -0.416613  ...  4.546613  3.740484          -0.646774  3.566667
#
#        Lagged Income  Large Bank  PredRate_lrm  Pred_Q_Income_lrm  \
# 15704       0.010513       False      0.011520        1633.091474
# 15705       0.009479       False      0.010886        3499.849823
# 15706       0.008953       False      0.010563       84674.599805
# 15707       0.011702       False      0.012250       55800.173636
# 15708       0.010202       False      0.011330       54041.013398
#
#        PredRate_rf  Pred_Q_Income_rf
# 15704     0.011685       1656.376765
# 15705     0.010387       3339.657177
# 15706     0.009905      79400.533211
# 15707     0.012853      58544.685738
# 15708     0.011778      56178.970648
#
# [5 rows x 72 columns]

# %% [markdown]
# **Repeat for the Regression Tree**

# %%
#Define the model
reg_tree = DecisionTreeRegressor(max_depth=3, random_state=42)

# Train the model
reg_tree.fit(X_train, y_train)

# Make predictions
y_predTree = reg_tree.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_predTree)
r2 = r2_score(y_test, y_predTree)

print(f'Mean Squared Error: {mse}')
print(f'R² Score: {r2}')
# Out:
# Mean Squared Error: 3.369834918715027e-06
# R² Score: 0.7916048836734833

# %%
data_test['PredRate_Tree']=y_predTree
data_test['Pred_Q_Income_Tree'] =  data_test['PredRate_Tree'] * data_test['Total Assets']
data_test.head()
# Out:
#        RSSD ID                       Firm Legal Name  FR District Code  \
# 15704  5478903                             CSBH, LLC                 5
# 15705  1142309  MIDWEST INDEPENDENT BANCSHARES, INC.                 8
# 15706  2385493           FIRST BANCSHARES, INC., THE                 6
# 15707  2737814          NORTHPOINTE BANCSHARES, INC.                 7
# 15708  1131497                  SMARTFINANCIAL, INC.                 6
#
#       Reporting Date  Total Assets  Year  Quarter  \
# 15704     2023-03-31      141756.0  2023        1
# 15705     2023-03-31      321513.0  2023        1
# 15706     2023-03-31     8016466.0  2023        1
# 15707     2023-03-31     4554982.0  2023        1
# 15708     2023-03-31     4769805.0  2023        1
#
#        Normalized Interest Income per Quarter  3 Yr-1 Yr_spread  \
# 15704                                0.010250         -0.684032
# 15705                                0.011381         -0.684032
# 15706                                0.010022         -0.684032
# 15707                                0.012713         -0.684032
# 15708                                0.011149         -0.684032
#
#        2 Yr-1 Yr_spread  ...  20 Yr-1 Mo_spread    UNRATE  Lagged Income  \
# 15704         -0.416613  ...          -0.646774  3.566667       0.010513
# 15705         -0.416613  ...          -0.646774  3.566667       0.009479
# 15706         -0.416613  ...          -0.646774  3.566667       0.008953
# 15707         -0.416613  ...          -0.646774  3.566667       0.011702
# 15708         -0.416613  ...          -0.646774  3.566667       0.010202
#
#        Large Bank  PredRate_lrm  Pred_Q_Income_lrm  PredRate_rf  \
# 15704       False      0.011520        1633.091474     0.011685
# 15705       False      0.010886        3499.849823     0.010387
# 15706       False      0.010563       84674.599805     0.009905
# 15707       False      0.012250       55800.173636     0.012853
# 15708       False      0.011330       54041.013398     0.011778
#
#        Pred_Q_Income_rf  PredRate_Tree  Pred_Q_Income_Tree
# 15704       1656.376765       0.009823         1392.435391
# 15705       3339.657177       0.009823         3158.145546
# 15706      79400.533211       0.008187        65628.631214
# 15707      58544.685738       0.011118        50642.259918
# 15708      56178.970648       0.009823        46852.657323
#
# [5 rows x 74 columns]

# %%
tmp_df = data_test.set_index("RSSD ID")
df5 = tmp_df.loc[rssd_id_5]
df5.reset_index(inplace=True)
df5.head()
# Out:
#    RSSD ID              Firm Legal Name  FR District Code Reporting Date  \
# 0  1039502         JPMORGAN CHASE & CO.                 2     2023-03-31
# 1  1039502         JPMORGAN CHASE & CO.                 2     2023-06-30
# 2  1039502         JPMORGAN CHASE & CO.                 2     2023-09-30
# 3  1039502         JPMORGAN CHASE & CO.                 2     2023-12-31
# 4  1073757  BANK OF AMERICA CORPORATION                 5     2023-03-31
#
#    Total Assets  Year  Quarter  Normalized Interest Income per Quarter  \
# 0  3.744305e+09  2023        1                                0.009905
# 1  3.868240e+09  2023        2                                0.010786
# 2  3.898333e+09  2023        3                                0.011467
# 3  3.875393e+09  2023        4                                0.012259
# 4  3.194657e+09  2023        1                                0.009057
#
#    3 Yr-1 Yr_spread  2 Yr-1 Yr_spread  ...  20 Yr-1 Mo_spread    UNRATE  \
# 0         -0.684032         -0.416613  ...          -0.646774  3.566667
# 1         -0.999365         -0.684444  ...          -1.036984  3.700000
# 2         -0.790635         -0.473333  ...          -1.064286  3.733333
# 3         -0.645968         -0.418065  ...          -0.777258  3.800000
# 4         -0.684032         -0.416613  ...          -0.646774  3.566667
#
#    Lagged Income  Large Bank  PredRate_lrm  Pred_Q_Income_lrm  PredRate_rf  \
# 0       0.009048        True      0.010621       3.976680e+07     0.010002
# 1       0.009905        True      0.011271       4.359797e+07     0.011469
# 2       0.010786        True      0.012046       4.695959e+07     0.012194
# 3       0.011467        True      0.012451       4.825429e+07     0.012443
# 4       0.008309        True      0.010167       3.248130e+07     0.009485
#
#    Pred_Q_Income_rf  PredRate_Tree  Pred_Q_Income_Tree
# 0      3.745129e+07       0.008187        3.065361e+07
# 1      4.436446e+07       0.009823        3.799680e+07
# 2      4.753656e+07       0.011118        4.334164e+07
# 3      4.822274e+07       0.011118        4.308659e+07
# 4      3.030011e+07       0.008187        2.615379e+07
#
# [5 rows x 74 columns]

# %% [markdown]
# Now, we go back to get the Quarterized Interest income of the banks in the years 2023

# %%
aux_df = Quarterized_dfs.set_index("RSSD ID")
q_df5 = aux_df.loc[rssd_id_5]
q_df5.reset_index(inplace=True)
# q_df5.head()

# %%
# Select the years as in our test data
q_df_ty = q_df5[q_df5["Year"] == 2023]
q_df_ty.head()
# Out:
#      RSSD ID              Firm Legal Name  FR District Code  Bank Count  \
# 76   1039502         JPMORGAN CHASE & CO.                 2         2.0
# 77   1039502         JPMORGAN CHASE & CO.                 2         2.0
# 78   1039502         JPMORGAN CHASE & CO.                 2         2.0
# 79   1039502         JPMORGAN CHASE & CO.                 2         2.0
# 157  1073757  BANK OF AMERICA CORPORATION                 5         2.0
#
#     Reporting Date  Interest Income  Total Assets  Quarter  Year  \
# 76      2023-03-31       37086000.0  3.744305e+09        1  2023
# 77      2023-06-30       78807000.0  3.868240e+09        2  2023
# 78      2023-09-30      123511000.0  3.898333e+09        3  2023
# 79      2023-12-31      171020000.0  3.875393e+09        4  2023
# 157     2023-03-31       28935000.0  3.194657e+09        1  2023
#
#      QInterest Income  Normalized Interest Income per Quarter
# 76         37086000.0                                0.009905
# 77         41721000.0                                0.010786
# 78         44704000.0                                0.011467
# 79         47509000.0                                0.012259
# 157        28935000.0                                0.009057

# %%
def plot_interest_income(actual_df, pred_df, bank_name):
    """
    This function plots the actual and predicted interest income
    for a specified bank.
    """
    actual = actual_df[actual_df["Firm Legal Name"] == bank_name]
    predicted = pred_df[pred_df["Firm Legal Name"] == bank_name]
    
    plt.figure(figsize=(8, 6))
    
    plt.plot(actual["Reporting Date"], actual["QInterest Income"], label = "Actual Interest Income", color = "k",
           marker="o", linestyle="-")
    plt.plot(predicted["Reporting Date"], predicted["Pred_Q_Income_lrm"], label = "Predicted Linear Regres", color = "r",
           marker="*", linestyle="dashed")
    plt.plot(predicted["Reporting Date"], predicted["Pred_Q_Income_rf"], label = "Predicted Random Forest", color = "g",
           marker="x", linestyle="dashed")
    plt.plot(predicted["Reporting Date"], predicted["Pred_Q_Income_Tree"], label = "Predicted Decision Tree", color = "b",
           marker="s", linestyle="dashed")
    
    plt.xlabel("Year - Quarter")
    plt.ylabel("Interest Income, $")
    plt.title(f"{bank_name} Interest Income for 2023")
    plt.legend()

    plt.xticks(list(JPM["Reporting Date"].astype(str).values))

    plt.show()

# %%
# List of banks to plot

banks = ["JPMORGAN CHASE & CO.", "BANK OF AMERICA CORPORATION", "CITIGROUP INC.",
         "GOLDMAN SACHS GROUP, INC., THE", "MORGAN STANLEY"]

# %%
for bank in banks:
    plot_interest_income(q_df_ty, df5, bank)
